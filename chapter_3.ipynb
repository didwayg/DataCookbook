# %% [markdown]
# # Chapter 3: Web Scraping Techniques
# Basic Web Scraping with Beautiful Soup: A recipe that guides through scraping data from a simple HTML website.

# %% [markdown]
# In the code below we will be using Beautiful Soup and requests to find chess game data from the chess player Judit Polgar, scrape it, and save it into a pandas dataframe.
#
# ** NOTE that before doing any scraping you should go to the site you would like to scrape and add /robots.txt to the url. This brings you to a page outlining what webscraping activity is permitted**

# %% [markdown]
# #### Import Necessary Libraries and Set Up Variables
# In this step, we import the required libraries, set the base URL for 365chess.com, and define the player's name (Judit Polgar) to be used in the URL.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the base URL and player name
base_url = "https://www.365chess.com/chess-games.php"
player_name = 'Polgar+Judit'
url = 'https://www.365chess.com/chess-games.php?wid=&bid=&wlname={}&openn=&blname=&eco=&nocolor=on&yeari=&yeare=&sply=1&ply=&res=&submit_search=1'.format(player_name)

# %% [markdown]
# #### Send a Request and Parse HTML Content
# Here, we send a GET request to the URL and parse the HTML content using BeautifulSoup.

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# #### Find the Game Data Table
# We locate the table containing game information on the webpage. Soup's .find method allows us to search for div tags with specific ids. Looking through the inspect code on the site we find the table for each game in the tbody tag in the div tage with id 'result1.

# %%
result = soup.find('div', id='result1')
table_body = result.find('tbody')

# %% [markdown]
# #### Extract Game Information
# In this step, we iterate through each game's row (<tr>) and extract specific details, such as player names, Elo ratings, results, moves, and more.

# %%
games = table_body.find_all('tr')
games_data = []
for game in games:
    details = game.find_all('td')
    game_info = {
        'white': details[0].text.strip(),
        'white_elo': details[1].text.strip(),
        'black': details[2].text.strip(),
        'black_elo': details[3].text.strip(),
        'result': details[4].text.strip(),
        'moves': details[5].text.strip(),
        'eco': details[6].text.strip(),
        'year': details[7].text.strip(),
        'tournament': details[8].text.strip(),
    }
    games_data.append(game_info)

# %% [markdown]
# #### Create a DataFrame and Display Data
# Finally, we convert the extracted game data into a Pandas DataFrame for easy analysis and display it.

# %%
df = pd.DataFrame(games_data)
df
# Out:
#                  white white_elo             black black_elo result moves  \
# 0            Polgar, J      2693    Goryachkina, A      2424    1-0    48
# 1        Gabrielian, A      2560         Polgar, J      2693    ½-½    71
# 2            Polgar, J      2693          Jianu, V      2574    1-0    46
# 3          Tregubov, P      2614         Polgar, J      2693    ½-½    59
# 4            Polgar, J      2693      Pashikian, A      2612    ½-½    48
# 5         Schlosser, P      2612         Polgar, J      2693    ½-½    60
# 6            Polgar, J      2693   Hovhannisyan, R      2611    ½-½    41
# 7           Dvirnyy, D      2575         Polgar, J      2693    0-1    50
# 8            Polgar, J      2693    Grigoriants, S      2574    0-1    36
# 9      Ter Sahakyan, S      2572         Polgar, J      2693    1-0    52
# 10           Polgar, J      2693         Yilmaz, M      2557    1-0    33
# 11         Gajewski, G      2650         Polgar, J      2685    ½-½    59
# 12           Polgar, J      2685      Wojtaszek, R      2715    ½-½    86
# 13           Polgar, J      2685          Socko, B      2622    ½-½    56
# 14          Swiercz, D      2613         Polgar, J      2685    1-0    24
# 15           Polgar, J      2685         Bartel, M      2641    0-1    35
# 16             Duda, J      2587         Polgar, J      2685    0-1    86
# 17           Polgar, J      2685      Alahakoon, I      2123    1-0     0
# 18          Mamedov, R      2659         Polgar, J      2685    0-1    52
# 19           Polgar, J      2685    Tomashevsky, E      2695    ½-½    52
# 20      Harikrishna, P      2726         Polgar, J      2685    0-1    43
# 21           Polgar, J      2685       Karjakin, S      2771    0-1    62
# 22       Morozevich, A      2731         Polgar, J      2685    1-0    26
# 23           Polgar, J      2685      Wojtaszek, R      2715    ½-½    51
# 24           Polgar, J      2685         Ragger, M      2632    ½-½    68
# 25           Potkin, V      2621         Polgar, J      2685    ½-½    70
# 26           Polgar, J      2685         Bacrot, E      2720    0-1    57
# 27               Lu, S      2546         Polgar, J      2685    1-0    47
# 28       Durarbayli, V      2590         Polgar, J      2685    ½-½    56
# 29           Polgar, J      2685  Ghaem Maghami, E      2582    ½-½    70
# 30         Michalik, P      2557         Polgar, J      2685    0-1    55
# 31           Polgar, J      2685        Kovalev, V      2554    ½-½    95
# 32          Ringoir, T      2506         Polgar, J      2685    0-1    41
# 33           Polgar, J      2685          Taleb, M      2406    1-0    38
# 34  Vachier Lagrave, M      2762         Polgar, J      2685    1-0    48
# 35           Polgar, J      2685             Yu, Y      2675    1-0    28
# 36       Morozevich, A      2731         Polgar, J      2685    ½-½    66
# 37           Polgar, J      2685      Wojtaszek, R      2715    1-0    68
# 38         Nakamura, H      2775         Polgar, J      2685    1-0    40
# 39           Polgar, J      2685      Onyshchuk, V      2594    1-0    36
# 40       Mamedyarov, S      2743         Polgar, J      2685    1-0    11
# 41           Polgar, J      2685         Nguyen, N      2621    1-0    46
# 42         Karjakin, S      2771         Polgar, J      2685    0-1    58
# 43           Polgar, J      2685        Caruana, F      2791    1-0    58
# 44           Polgar, J      2685          Meier, G      2632    ½-½    44
# 45          Carlsen, M      2881         Polgar, J      2685    1-0    39
# 46           Polgar, J      2685    Tomashevsky, E      2695    1-0    55
# 47           Polgar, J      2685          Anand, V      2785    0-1    49
# 48               Le, Q      2712         Polgar, J      2685    ½-½    70
# 49           Polgar, J      2685       Grischuk, A      2792    ½-½    49
#
#     eco  year                     tournament
# 0   B12  2014         15th ch-EUR Indiv 2014
# 1   B33  2014         15th ch-EUR Indiv 2014
# 2   C07  2014         15th ch-EUR Indiv 2014
# 3   E17  2014         15th ch-EUR Indiv 2014
# 4   C65  2014         15th ch-EUR Indiv 2014
# 5   A33  2014         15th ch-EUR Indiv 2014
# 6   C67  2014         15th ch-EUR Indiv 2014
# 7   A36  2014         15th ch-EUR Indiv 2014
# 8   C84  2014         15th ch-EUR Indiv 2014
# 9   B48  2014         15th ch-EUR Indiv 2014
# 10  B90  2014         15th ch-EUR Indiv 2014
# 11  E11  2014  HUN-POL Friendly Match m 2014
# 12  B51  2014  HUN-POL Friendly Match m 2014
# 13  C42  2014  HUN-POL Friendly Match m 2014
# 14  E35  2014  HUN-POL Friendly Match m 2014
# 15  B57  2014  HUN-POL Friendly Match m 2014
# 16  B83  2014  HUN-POL Friendly Match m 2014
# 17       2014          FIDE World Rapid 2014
# 18  B22  2014          FIDE World Rapid 2014
# 19  C88  2014          FIDE World Rapid 2014
# 20  A46  2014          FIDE World Rapid 2014
# 21  B90  2014          FIDE World Rapid 2014
# 22  B20  2014          FIDE World Rapid 2014
# 23  B51  2014          FIDE World Rapid 2014
# 24  C90  2014          FIDE World Rapid 2014
# 25  E16  2014          FIDE World Rapid 2014
# 26  C67  2014          FIDE World Rapid 2014
# 27  B30  2014          FIDE World Rapid 2014
# 28  B33  2014          FIDE World Rapid 2014
# 29  C84  2014          FIDE World Rapid 2014
# 30  E70  2014          FIDE World Rapid 2014
# 31  C86  2014          FIDE World Rapid 2014
# 32  E81  2014          FIDE World Blitz 2014
# 33  B31  2014          FIDE World Blitz 2014
# 34  B30  2014          FIDE World Blitz 2014
# 35  B42  2014          FIDE World Blitz 2014
# 36  B20  2014          FIDE World Blitz 2014
# 37  B51  2014          FIDE World Blitz 2014
# 38  A45  2014          FIDE World Blitz 2014
# 39  B09  2014          FIDE World Blitz 2014
# 40  A45  2014          FIDE World Blitz 2014
# 41  C10  2014          FIDE World Blitz 2014
# 42  B48  2014          FIDE World Blitz 2014
# 43  C02  2014          FIDE World Blitz 2014
# 44  C10  2014          FIDE World Blitz 2014
# 45  E81  2014          FIDE World Blitz 2014
# 46  C88  2014          FIDE World Blitz 2014
# 47  B90  2014          FIDE World Blitz 2014
# 48  A45  2014          FIDE World Blitz 2014
# 49  B90  2014          FIDE World Blitz 2014
